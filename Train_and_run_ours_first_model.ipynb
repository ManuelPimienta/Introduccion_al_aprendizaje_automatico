# %%
import pandas

# %%
# Make a dictionary of data for boot sizes
# and harness size in cm
data = {
    'boot_size' : [ 39, 38, 37, 39, 38, 35, 37, 36, 35, 40, 
                    40, 36, 38, 39, 42, 42, 36, 36, 35, 41, 
                    42, 38, 37, 35, 40, 36, 35, 39, 41, 37, 
                    35, 41, 39, 41, 42, 42, 36, 37, 37, 39,
                    42, 35, 36, 41, 41, 41, 39, 39, 35, 39
 ],
    'harness_size': [ 58, 58, 52, 58, 57, 52, 55, 53, 49, 54,
                59, 56, 53, 58, 57, 58, 56, 51, 50, 59,
                59, 59, 55, 50, 55, 52, 53, 54, 61, 56,
                55, 60, 57, 56, 61, 58, 53, 57, 57, 55,
                60, 51, 52, 56, 55, 57, 58, 57, 51, 59
                ]
}

# %%
# Convertir los datos en tabla con pandas
dataset = pandas.DataFrame(data)
dataset
# Out:
#     boot_size  harness_size
# 0          39            58
# 1          38            58
# 2          37            52
# 3          39            58
# 4          38            57
# 5          35            52
# 6          37            55
# 7          36            53
# 8          35            49
# 9          40            54
# 10         40            59
# 11         36            56
# 12         38            53
# 13         39            58
# 14         42            57
# 15         42            58
# 16         36            56
# 17         36            51
# 18         35            50
# 19         41            59
# 20         42            59
# 21         38            59
# 22         37            55
# 23         35            50
# 24         40            55
# 25         36            52
# 26         35            53
# 27         39            54
# 28         41            61
# 29         37            56
# 30         35            55
# 31         41            60
# ...

# %% [markdown]
# # Seleccionar un modelo

# %%
pip install statsmodels

# %%
# Cargar la libreria
import statsmodels.formula.api as smf

# definimos la formula como boot size explicada por harness size
formula = "boot_size ~ harness_size"

# Creamos el modelo
model = smf.ols(formula = formula, data = dataset)

# Aun no tiene parametros
if not hasattr(model, 'params'):
    print("Model selected but it does not have parameters ser.")
# Out:
# Model selected but it does not have parameters ser.

# %% [markdown]
# # Entrenar el modelo

# %%
fitted_model = model.fit()

# Print information about our model now it has been fit
print("The following model parameters have been found:\n" +
        f"Line slope: {fitted_model.params[1]}\n"+
        f"Line Intercept: {fitted_model.params[0]}")
# Out:
# The following model parameters have been found:
# Line slope: 0.5859254167382717
# Line Intercept: 5.719109812682555

# %% [markdown]
# ## Usar el modelo

# %%
# Estamos interezados en un tipo de harness
harness_size = { 'harness_size' : [52.5]}

# Prediccion
approximate_boot_size = fitted_model.predict(harness_size)

# Print el resultado
print('Resultado aproximado')
print(approximate_boot_size)
# Out:
# Resultado aproximado
# 0    36.480194
# dtype: float64
